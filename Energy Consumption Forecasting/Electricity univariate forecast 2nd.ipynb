# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('ggplot')

# %%
df = pd.read_csv('PJMW_hourly.csv')
df = df.set_index('Datetime')
df.index = pd.to_datetime(df.index)

# %% [markdown]
# ## Plotting

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143206 entries, 2002-12-31 01:00:00 to 2018-01-02 00:00:00
# Data columns (total 1 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   PJMW_MW  143206 non-null  float64
# dtypes: float64(1)
# memory usage: 2.2 MB

# %%
df.plot(style = '.', color = color_pal[2], title = 'PJMW Energy Consumption')
plt.xlabel('Energy Consumption')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.histplot(data =df, x = df['PJMW_MW'], color=color_pal[4])
# Out:
# <Axes: xlabel='PJMW_MW', ylabel='Count'>

# %%
df.query('PJMW_MW < 3_300')['PJMW_MW'].plot(figsize = (11,6), title = 'Detect Outlier', style = '.')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df_copy = df.query('PJMW_MW > 2_500').copy()

# %% [markdown]
# ## Train/Test Split

# %%
train = df_copy.loc[df_copy.index < '2015-01-01']
test = df_copy.loc[df_copy.index >= '2015-01-01']

# %%
fig, ax = plt.subplots(figsize = (15,5))
train.plot(ax = ax, label = 'Training Plot', title = 'Train and Test Data')
test.plot(ax = ax, label = 'Test Plot')
ax.legend(['Train data', 'Test data'])
ax.axvline(x = df_copy.index[df_copy.index == '2015-01-01'], ls = '--', color = color_pal[4])
plt.show()

# %% [markdown]
# ## Time Series Cross Validation

# %%
from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits=5, test_size=365*24*1, gap = 24)

# %%
df_copy = df_copy.sort_index()

# %%
fig, axs = plt.subplots(5,1, figsize = (15,8), sharex = True)

fold = 0
for train_indx, val_indx in tss.split(df_copy):
        train = df_copy.iloc[train_indx]
        test = df_copy.iloc[val_indx]
        train['PJMW_MW'].plot(ax=axs[fold], title = f'Data Train/Test Fold {fold}', label = 'Training Set')
        test['PJMW_MW'].plot(ax=axs[fold], label = 'Test Set')
        axs[fold].axvline(test.index.min(), ls = '--', color = color_pal[5])
        fold += 1

plt.show()

# %% [markdown]
# ## Forecasting Horizon
#
# The Forecasting Horizon is the length time into the future for which forecast are to be prepared.

# %%
def create_features (data):
    
    data = data.copy()
    data['Hour'] = data.index.hour
    data['dayofweek'] = data.index.dayofweek
    data['month'] = data.index.month
    data['quarter'] = data.index.quarter
    data['year'] = data.index.year
    data['dayofyear'] = data.index.dayofyear
    data['dayofmonth'] = data.index.day
    data['weekofyear'] = data.index.isocalendar().week
    return data

df2 = create_features(df_copy)

# %% [markdown]
# ## Lag Features
#
# A values at prior timestamp that are considered useful due to they are created on an assumption that what happened in the past could influence sort of intrinsic information about the future.

# %%
def add_lag (data):
    target_map = df['PJMW_MW'].to_dict()
    data['lag1'] = (data.index - pd.Timedelta('364 days')).map(target_map)
    data['lag2'] = (data.index - pd.Timedelta('728 days')).map(target_map)
    data['lag3'] = (data.index - pd.Timedelta('1092 days')).map(target_map)
    return data

# %%
df_lag = add_lag(df2)

# %% [markdown]
# ## Train Using Cross Validation

# %%
from xgboost import XGBRegressor
import numpy as np
from sklearn.metrics import mean_squared_error

tss = TimeSeriesSplit(n_splits=5, test_size=365*24*1, gap = 24)
df_lag = df_lag.sort_index()

fold = 0
pred = []
scores = []
for train_indx, val_indx in tss.split(df_lag):
    train = df_lag.iloc[train_indx]
    test = df_lag.iloc[val_indx]
    
    train = create_features(train)
    test = create_features(test)
    
    features = ['Hour', 'dayofweek', 'month', 'quarter', 'year', 'dayofyear', 'dayofmonth', 'lag1', 'lag2', 'lag3']
    label = 'PJMW_MW'
    
    X_train = train[features]
    y_train = train[label]
    
    X_test = test[features]
    y_test = test[label]
    
    reg = XGBRegressor(n_estimators = 2000, max_depth = 3, objective = 'reg:linear', early_stopping_rounds = 50, learning_rate = 0.001, booster = 'gbtree')
    
    reg.fit(X_train, y_train, eval_set = [(X_train, y_train), (X_test, y_test)], verbose = 100)
    
    y_pred = reg.predict(X_test)
    pred.append(y_pred)
    score = np.sqrt(mean_squared_error (y_test, y_pred))
    scores.append(score)
# Out:
# [09:31:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:5676.16878	validation_1-rmse:5738.66962
# [100]	validation_0-rmse:5143.04561	validation_1-rmse:5216.35860
# [200]	validation_0-rmse:4661.32717	validation_1-rmse:4745.39048
# [300]	validation_0-rmse:4226.14882	validation_1-rmse:4320.63201
# [400]	validation_0-rmse:3833.11571	validation_1-rmse:3936.99224
# [500]	validation_0-rmse:3478.24334	validation_1-rmse:3590.83254
# [600]	validation_0-rmse:3157.89903	validation_1-rmse:3279.58105
# [700]	validation_0-rmse:2868.96402	validation_1-rmse:2998.92492
# [800]	validation_0-rmse:2608.44046	validation_1-rmse:2746.06809
# [900]	validation_0-rmse:2373.63120	validation_1-rmse:2518.06470
# [1000]	validation_0-rmse:2162.29800	validation_1-rmse:2312.57857
# [1100]	validation_0-rmse:1972.27958	validation_1-rmse:2128.20972
# [1200]	validation_0-rmse:1801.68627	validation_1-rmse:1962.83482
# [1300]	validation_0-rmse:1648.72564	validation_1-rmse:1815.26664
# [1400]	validation_0-rmse:1511.78274	validation_1-rmse:1682.77723
# [1500]	validation_0-rmse:1389.36928	validation_1-rmse:1564.44687
# [1600]	validation_0-rmse:1279.96154	validation_1-rmse:1457.24794
# [1700]	validation_0-rmse:1182.67700	validation_1-rmse:1361.92050
# [1800]	validation_0-rmse:1096.17385	validation_1-rmse:1276.50216
# [1900]	validation_0-rmse:1019.52392	validation_1-rmse:1200.44269
# [1999]	validation_0-rmse:952.50481	validation_1-rmse:1132.41715
# [09:32:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:5681.20882	validation_1-rmse:5814.40029
# [100]	validation_0-rmse:5147.72180	validation_1-rmse:5290.93203
# [200]	validation_0-rmse:4665.67193	validation_1-rmse:4819.37735
# [300]	validation_0-rmse:4230.21800	validation_1-rmse:4392.45340
# [400]	validation_0-rmse:3836.94433	validation_1-rmse:4007.33012
# [500]	validation_0-rmse:3481.89764	validation_1-rmse:3658.70743
# [600]	validation_0-rmse:3161.42113	validation_1-rmse:3345.12832
# [700]	validation_0-rmse:2872.25782	validation_1-rmse:3063.93551
# [800]	validation_0-rmse:2611.59029	validation_1-rmse:2808.58656
# [900]	validation_0-rmse:2376.74599	validation_1-rmse:2578.42821
# [1000]	validation_0-rmse:2165.39994	validation_1-rmse:2371.88758
# [1100]	validation_0-rmse:1975.41551	validation_1-rmse:2185.90641
# [1200]	validation_0-rmse:1804.83428	validation_1-rmse:2019.65399
# [1300]	validation_0-rmse:1651.94271	validation_1-rmse:1869.98141
# [1400]	validation_0-rmse:1515.06684	validation_1-rmse:1734.89129
# [1500]	validation_0-rmse:1392.72147	validation_1-rmse:1613.29811
# [1600]	validation_0-rmse:1283.63012	validation_1-rmse:1505.78092
# [1700]	validation_0-rmse:1186.67456	validation_1-rmse:1408.91767
# [1800]	validation_0-rmse:1100.74995	validation_1-rmse:1322.85796
# [1900]	validation_0-rmse:1024.51846	validation_1-rmse:1244.76547
# [1999]	validation_0-rmse:957.67720	validation_1-rmse:1174.00609
# [09:33:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:5691.09639	validation_1-rmse:5520.97475
# [100]	validation_0-rmse:5156.81984	validation_1-rmse:4987.38030
# [200]	validation_0-rmse:4674.06355	validation_1-rmse:4506.28752
# [300]	validation_0-rmse:4237.97277	validation_1-rmse:4072.01414
# [400]	validation_0-rmse:3844.15287	validation_1-rmse:3680.49844
# [500]	validation_0-rmse:3488.61894	validation_1-rmse:3326.51618
# [600]	validation_0-rmse:3167.74607	validation_1-rmse:3007.96628
# [700]	validation_0-rmse:2878.22684	validation_1-rmse:2722.08733
# [800]	validation_0-rmse:2617.30496	validation_1-rmse:2464.67255
# [900]	validation_0-rmse:2382.27187	validation_1-rmse:2233.75883
# [1000]	validation_0-rmse:2170.71290	validation_1-rmse:2025.67214
# [1100]	validation_0-rmse:1980.53466	validation_1-rmse:1838.96716
# [1200]	validation_0-rmse:1809.84216	validation_1-rmse:1671.55641
# [1300]	validation_0-rmse:1656.85584	validation_1-rmse:1521.89052
# [1400]	validation_0-rmse:1519.92067	validation_1-rmse:1388.96103
# [1500]	validation_0-rmse:1397.43772	validation_1-rmse:1267.06693
# [1600]	validation_0-rmse:1288.24699	validation_1-rmse:1159.92147
# [1700]	validation_0-rmse:1191.20923	validation_1-rmse:1066.92840
# [1800]	validation_0-rmse:1105.18103	validation_1-rmse:985.80847
# [1900]	validation_0-rmse:1028.70851	validation_1-rmse:914.43228
# [1999]	validation_0-rmse:961.95763	validation_1-rmse:854.52216
# [09:34:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:5679.32883	validation_1-rmse:5605.39915
# [100]	validation_0-rmse:5146.22788	validation_1-rmse:5084.66081
# [200]	validation_0-rmse:4664.54298	validation_1-rmse:4614.05572
# [300]	validation_0-rmse:4229.42844	validation_1-rmse:4188.82273
# [400]	validation_0-rmse:3836.50252	validation_1-rmse:3803.88358
# [500]	validation_0-rmse:3481.77948	validation_1-rmse:3456.32050
# [600]	validation_0-rmse:3161.64186	validation_1-rmse:3142.93407
# [700]	validation_0-rmse:2872.91681	validation_1-rmse:2860.15252
# [800]	validation_0-rmse:2612.69571	validation_1-rmse:2605.91936
# [900]	validation_0-rmse:2378.23505	validation_1-rmse:2376.94263
# [1000]	validation_0-rmse:2167.20227	validation_1-rmse:2171.19515
# [1100]	validation_0-rmse:1977.59451	validation_1-rmse:1986.32852
# [1200]	validation_0-rmse:1807.44778	validation_1-rmse:1820.82005
# [1300]	validation_0-rmse:1654.94795	validation_1-rmse:1673.51547
# [1400]	validation_0-rmse:1518.52031	validation_1-rmse:1542.08582
# [1500]	validation_0-rmse:1396.58882	validation_1-rmse:1425.61894
# [1600]	validation_0-rmse:1287.93699	validation_1-rmse:1321.91343
# [1700]	validation_0-rmse:1191.47450	validation_1-rmse:1230.56490
# [1800]	validation_0-rmse:1105.89326	validation_1-rmse:1150.39805
# [1900]	validation_0-rmse:1030.20667	validation_1-rmse:1080.25530
# [1999]	validation_0-rmse:964.14309	validation_1-rmse:1019.69624
# [09:35:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:5674.55582	validation_1-rmse:5780.78451
# [100]	validation_0-rmse:5142.01047	validation_1-rmse:5255.31436
# [200]	validation_0-rmse:4660.84467	validation_1-rmse:4781.43090
# [300]	validation_0-rmse:4226.21672	validation_1-rmse:4354.28170
# [400]	validation_0-rmse:3833.75422	validation_1-rmse:3968.10594
# [500]	validation_0-rmse:3479.46604	validation_1-rmse:3619.52931
# [600]	validation_0-rmse:3159.75179	validation_1-rmse:3305.71044
# [700]	validation_0-rmse:2871.44321	validation_1-rmse:3023.06483
# [800]	validation_0-rmse:2611.60119	validation_1-rmse:2767.98966
# [900]	validation_0-rmse:2377.56558	validation_1-rmse:2537.26395
# [1000]	validation_0-rmse:2166.97164	validation_1-rmse:2329.32965
# [1100]	validation_0-rmse:1977.76812	validation_1-rmse:2142.15435
# [1200]	validation_0-rmse:1808.02905	validation_1-rmse:1974.09219
# [1300]	validation_0-rmse:1655.98487	validation_1-rmse:1823.56807
# [1400]	validation_0-rmse:1520.01293	validation_1-rmse:1688.61547
# [1500]	validation_0-rmse:1398.61197	validation_1-rmse:1568.48380
# [1600]	validation_0-rmse:1290.38432	validation_1-rmse:1463.35512
# [1700]	validation_0-rmse:1194.32911	validation_1-rmse:1369.29609
# [1800]	validation_0-rmse:1109.36841	validation_1-rmse:1284.39377
# [1900]	validation_0-rmse:1034.25931	validation_1-rmse:1209.24383
# [1999]	validation_0-rmse:968.58141	validation_1-rmse:1141.52533

# %%
print (f'RMSE score accros fold {np.mean(scores):0.4f}')
print(f'RMSE score each fold {scores}')
# Out:
# RMSE score accros fold 1064.4334
# RMSE score each fold [1132.4171538455091, 1174.0060869052816, 854.5221554924897, 1019.6962409376423, 1141.5253321267187]

# %%
Fold = [1,2,3,4,5]
fold_result= pd.Series(data = scores, index = Fold)

# %%
fold_result.sort_values(ascending = False).plot(kind = 'barh', color = color_pal[1])
plt.xlabel('RMSE score')
plt.ylabel('Nth Folds')
plt.title('RMSE Score each XGB folds')
# Out:
# Text(0.5, 1.0, 'RMSE Score each XGB folds')

# %% [markdown]
# ## Future Prediction
#
# - Retaining on all data
# - Need an empty dataset for predict future
# - Run those dates through feature creation code + lag creation

# %%
# Retaining on all data

df_lag = create_features(df_lag)

features = ['Hour', 'dayofweek', 'month', 'quarter', 'year', 'dayofyear', 'dayofmonth', 'lag1', 'lag2', 'lag3']
label = 'PJMW_MW'

X_all = df_lag[features]
y_all = df_lag[label]

reg = XGBRegressor(booster = 'gbtree', max_depth = 3, n_estimators = 1200, learning_rate = 0.001, objective = 'reg:linear')

reg.fit(X_all, y_all, eval_set = [(X_all, y_all)], verbose = 100)
# Out:
# [10:08:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:5681.21293
# [100]	validation_0-rmse:5148.07109
# [200]	validation_0-rmse:4666.37231
# [300]	validation_0-rmse:4231.27814
# [400]	validation_0-rmse:3838.40918
# [500]	validation_0-rmse:3483.77265
# [600]	validation_0-rmse:3163.78862
# [700]	validation_0-rmse:2875.19323
# [800]	validation_0-rmse:2615.11210
# [900]	validation_0-rmse:2380.97084
# [1000]	validation_0-rmse:2170.21182
# [1100]	validation_0-rmse:1980.88108
# [1199]	validation_0-rmse:1812.64649
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1200, n_jobs=None, num_parallel_tree=None,
#              objective='reg:linear', predictor=None, ...)

# %%
# end date in df_lag
df_lag.index.max()
# Out:
# Timestamp('2018-08-03 00:00:00')

# %%
# Create future dataset

future = pd.date_range('2018-08-03', '2019-08-01', freq = '1h')
future_df = pd.DataFrame(index = future)
future_df['isFuture'] = True
df_lag['isFuture'] = False
df_and_future = pd.concat([df_lag, future_df])
df_and_future = create_features(df_and_future)
df_and_future = add_lag(df_and_future)
df_and_future
# Out:
#                      PJMW_MW  Hour  dayofweek  month  quarter  year  \
# 2002-04-01 01:00:00   4374.0     1          0      4        2  2002
# 2002-04-01 02:00:00   4306.0     2          0      4        2  2002
# 2002-04-01 03:00:00   4322.0     3          0      4        2  2002
# 2002-04-01 04:00:00   4359.0     4          0      4        2  2002
# 2002-04-01 05:00:00   4436.0     5          0      4        2  2002
# ...                      ...   ...        ...    ...      ...   ...
# 2019-07-31 20:00:00      NaN    20          2      7        3  2019
# 2019-07-31 21:00:00      NaN    21          2      7        3  2019
# 2019-07-31 22:00:00      NaN    22          2      7        3  2019
# 2019-07-31 23:00:00      NaN    23          2      7        3  2019
# 2019-08-01 00:00:00      NaN     0          3      8        3  2019
#
#                      dayofyear  dayofmonth  weekofyear    lag1    lag2  \
# 2002-04-01 01:00:00         91           1          14     NaN     NaN
# 2002-04-01 02:00:00         91           1          14     NaN     NaN
# 2002-04-01 03:00:00         91           1          14     NaN     NaN
# 2002-04-01 04:00:00         91           1          14     NaN     NaN
# 2002-04-01 05:00:00         91           1          14     NaN     NaN
# ...                        ...         ...         ...     ...     ...
# 2019-07-31 20:00:00        212          31          31  6816.0  7240.0
# 2019-07-31 21:00:00        212          31          31  6571.0  6970.0
# 2019-07-31 22:00:00        212          31          31  6362.0  6697.0
# 2019-07-31 23:00:00        212          31          31  5881.0  6250.0
# 2019-08-01 00:00:00        213           1          31  5363.0  5591.0
#
#                        lag3  isFuture
# 2002-04-01 01:00:00     NaN     False
# 2002-04-01 02:00:00     NaN     False
# 2002-04-01 03:00:00     NaN     False
# 2002-04-01 04:00:00     NaN     False
# 2002-04-01 05:00:00     NaN     False
# ...                     ...       ...
# 2019-07-31 20:00:00  6951.0      True
# 2019-07-31 21:00:00  6864.0      True
# 2019-07-31 22:00:00  6670.0      True
# 2019-07-31 23:00:00  6162.0      True
# 2019-08-01 00:00:00  5647.0      True
#
# [151918 rows x 13 columns]

# %%
future_w_features = df_and_future.query('isFuture').copy()

# %% [markdown]
# ## Predict the Future

# %%
future_w_features['pred'] =  reg.predict(future_w_features[features])

# %%
future_w_features['pred'].plot(figsize =  (13,5), title = 'Future Prediction',  color = color_pal[2], ms = 1)
plt.show()

# %% [markdown]
# ## How to save model (BONUS)

# %%
reg.save_model('XGBregressor.json')

# %%
reg_new = XGBRegressor()
reg_new.load_model('XGBregressor.json')
future_w_features['pred'] = reg_new.predict(future_w_features[features])
future_w_features['pred'].plot(figsize = (13,5), color = color_pal[3], ms = 1, lw = 1, title = 'Future Prediction')
# Out:
# <Axes: title={'center': 'Future Prediction'}>
