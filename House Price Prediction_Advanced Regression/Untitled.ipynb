# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
L_c = np.arange(1,10,1)
L_a = 10
r_f = L_a/L_c
eff = 100- ((2**(2/3))*(L_c/L_a)**(2))
plt.plot(F_c, eff)
plt.xlabel('Compression Ratio')
plt.ylabel('Efficiency')
plt.show()
